# %%
import matplotlib.pyplot as plt  #pyplot is used for plotting

import numpy as np

#Indian Players
xpoint = np.array(["I1","I2","I3","I4","I5","I6","I7","I8","I9","I10","I11"])
#Their Series match each player performance

ypoint11 = np.array([80,92,68,79,54,35,28,22,32,15,5]) 
newcolors = np.array(["lightskyblue","gold","purple","violet","green","orange","magenta","skyblue","yellow","red","grey"])
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("India")
plt.bar(xpoint,ypoint11,color = newcolors)

#South Africa Players
xpoint2 = np.array(["S1","S2","S3","S4","S5","S6","S7","S8","S9","S10","S11"]) 
#Their Series match each player performance
ypoint12 = np.array([79,80,68,76,45,32,32,20,50,18,0])  
plt.subplot(1,2,2)
plt.title("South Africa")
plt.bar(xpoint2,ypoint12,color = newcolors)

plt.suptitle("Batting Performance In First series")
plt.show()


#Second Series match each player performance
ypoint12 = np.array([80,20,35,95,8,5,45,63,0,5,20]) 
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("India")
plt.bar(xpoint,ypoint12,color = newcolors)
#Their Series match each player performance
ypoint22 = np.array([56,67,60,58,95,20,30,34,0,18,5])  
plt.subplot(1,2,2)
plt.title("South Africa")
plt.bar(xpoint2,ypoint22,color = newcolors)
plt.suptitle("Batting Performance In Second series")
plt.show()


#Third Series match each player performance
ypoint13 = np.array([5,80,15,60,58,85,45,35,10,15,20]) 
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("India")
plt.bar(xpoint,ypoint13,color = newcolors)
#Their Series match each player performance
ypoint23 = np.array([50,35,90,58,65,20,15,4,40,18,10])  
plt.subplot(1,2,2)
plt.title("South Africa")
plt.bar(xpoint2,ypoint23,color = newcolors)

plt.suptitle("Batting Performance In Third series")
plt.show()

# %%
import matplotlib.pyplot as plt  #pyplot is used for plotting

import numpy as np

#first  Series match each player performance
xpoint11 = np.array([80,92,68,79,54,35,28,22,32,15,5])
lables1 = np.array(["I1","I2","I3","I4","I5","I6","I7","I8","I9","I10","I11"])
newcolors = np.array(["lightskyblue","gold","purple","violet","green","orange","magenta","skyblue","yellow","red","grey"])
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.pie(xpoint11,labels=lables1,colors=newcolors,autopct='%1.1f%%')#percentage

plt.legend(title="India",bbox_to_anchor=(0.015,1),ncol=1) 


xpoint12 = np.array([79,80,68,76,45,32,32,20,50,18,0])
lable2 = np.array(["S1","S2","S3","S4","S5","S6","S7","S8","S9","S10","S11"])
plt.subplot(1,2,2)
plt.pie(xpoint12,labels=lable2,colors=newcolors,autopct='%1.1f%%')#percentage

plt.legend(title="South Africa",bbox_to_anchor=(1.3,1),ncol=1) 
plt.suptitle("Batting Performance In First series")




#Second  Series match each player performance
xpoint21 = np.array([80,20,35,95,8,5,45,63,0,5,20])
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.pie(xpoint21,labels=lables1,colors=newcolors,autopct='%1.1f%%')#percentage

plt.legend(title="India",bbox_to_anchor=(0.015,1),ncol=1) 


xpoint22 = np.array([56,67,60,58,95,20,30,34,0,18,70])
plt.subplot(1,2,2)
plt.pie(xpoint22,labels=lable2,colors=newcolors,autopct='%1.1f%%')#percentage

plt.legend(title="South Africa",bbox_to_anchor=(1.3,1),ncol=1) 
plt.suptitle("Batting Performance In Second  series")


#Third  Series match each player performance
xpoint31 = np.array([5,80,15,60,58,85,45,35,10,15,20])
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.pie(xpoint31,labels=lables1,colors=newcolors,autopct='%1.1f%%')#percentage

plt.legend(title="India",bbox_to_anchor=(0.015,1),ncol=1) 


xpoint32 = np.array([50,35,90,58,65,20,15,4,40,18,110])
plt.subplot(1,2,2)
plt.pie(xpoint32,labels=lable2,colors=newcolors,autopct='%1.1f%%')#percentage

plt.legend(title="South Africa",bbox_to_anchor=(1.3,1),ncol=1) 
plt.suptitle("Batting Performance In Third series")



plt.show()

# %%
import numpy as np

# Each Player Results max-performance is 100% and min-performance 0

#Indian Players
# There are six Bowlers .
xpoint = np.array(["I1","I2","I3","I4","I5","I6"])
newcolors = np.array(["lightskyblue","gold","purple","violet","green","orange"])
#Their Series match each player performance
ypoint11 = np.array([4,1,0,0,0,3]) 
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("India")
plt.bar(xpoint,ypoint11,color = newcolors)

#South Africa Players
# There are six Bowlers.
xpoint2 = np.array(["S1","S2","S3","S4","S5","S6"]) 
#Their Series match each player performance
ypoint12 = np.array([2,0,1,2,3,0])  
plt.subplot(1,2,2)
plt.title("South Africa")
plt.bar(xpoint2,ypoint12,color = newcolors)

plt.suptitle("Bowling Performance in  first series")



#performance in the second match
ypoint21 = np.array([3,1,0,1,0,1]) 
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("India")
plt.bar(xpoint,ypoint21,color = newcolors)

#Australia Players
# There are six Bowlers.
ypoint22 = np.array([1,3,1,2,1,0])  
plt.subplot(1,2,2)
plt.title("South Africa")
plt.bar(xpoint2,ypoint22,color = newcolors)
plt.suptitle("Bowling Performance in Second Series ")



#performance in the Third match
ypoint31 = np.array([2,1,3,1,0,1]) 
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("India")
plt.bar(xpoint,ypoint31,color = newcolors)

#Australia Players
# There are six Bowlers.
ypoint32 = np.array([2,0,1,2,1,0])  
plt.subplot(1,2,2)
plt.title("South Africa")
plt.bar(xpoint2,ypoint32,color = newcolors)
plt.suptitle("Bowling Performance in Third Series ")




plt.show()

# %%
import matplotlib.pyplot as plt  #pyplot is used for plotting

import numpy as np

#Their Series match each player performance
#No.of Wickets taken
xpoint11 = np.array([4,1,0,0,0,3])
#Indian Bowlers
lables1 = np.array(["I1","I2","I3","I4","I5","I6"])
newcolors = np.array(["lightskyblue","gold","purple","violet","green","orange"])
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.pie(xpoint11,labels=lables1,autopct='%1.1f%%')#percentage
plt.legend(title="India",bbox_to_anchor=(0.015,1),ncol=1) 

#No.of wickets taken
xpoint12 = np.array([2,0,1,2,3,0])
#South Africa Bowlers
lable2 = np.array(["S1","S2","S3","S4","S5","S6"])
plt.subplot(1,2,2)
plt.pie(xpoint12,labels=lable2,autopct='%1.1f%%')#percentage
plt.legend(title="South Africa",bbox_to_anchor=(1.3,1),ncol=1) 
plt.suptitle("Bowling Performance in First series")




xpoint21 = np.array([3,1,0,1,0,1])
#Indian Bowlers
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.pie(xpoint21,labels=lables1,autopct='%1.1f%%')#percentage
plt.legend(title="India",bbox_to_anchor=(0.015,1),ncol=1) 

#No.of wickets taken
xpoint22 = np.array([1,3,1,2,1,0])
#South Africa Bowlers
plt.subplot(1,2,2)
plt.pie(xpoint22,labels=lable2,autopct='%1.1f%%')#percentage
plt.legend(title="South Africa",bbox_to_anchor=(1.3,1),ncol=1) 
plt.suptitle("Bowling Performance in the Second series")





xpoint31 = np.array([2,1,3,1,0,1])
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.pie(xpoint31,labels=lables1,autopct='%1.1f%%')#percentage
plt.legend(title="India",bbox_to_anchor=(0.015,1),ncol=1) 

#No.of wickets taken
xpoint32 = np.array([2,0,1,2,1,0])
#Australian Bowlers
plt.subplot(1,2,2)
plt.pie(xpoint32,labels=lable2,autopct='%1.1f%%')#percentage
plt.legend(title="South Africa",bbox_to_anchor=(1.3,1),ncol=1) 
plt.suptitle("Bowling Performance in Third series")






plt.show()
